# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:

    '''
    La clase tienda tiene los siguientes atributos:
    Tipo
    Abierta
    '''

    tipo='Electrodomesticos'
    abierta= True

# Se crea el constructor con sus atributos

    def __init__ (self,nombre,direccion,empleados,ventas):
        self.nombre=nombre
        self.direccion=direccion
        self.empleados=empleados
        self.ventas=ventas

# Procedimiento para sumar las ventas de las tiendas

    def sumaventas(tienda):
        return sum(tienda.ventas)

    
# Procedimiento para sacar la media de ventas por empleado

    def ventasempleado(tienda):
        return sum(tienda.ventas)/tienda.empleados


# Procedimiento para sacar la tienda y la direccion

    def tiendadir(tienda):
       return tienda.nombre, tienda.direccion
      
    
# Procedimiento para sacar las ventas del mes   

    def ventasmes(tienda):
        return tienda.ventas[-1:-5:-1]



# Procedimiento ventas 3 meses

    def ventas3meses(tienda,x):
        if x < 1000:
            return sum(tienda.ventas)*1.2

        if x >= 1000:
            return sum(tienda.ventas)*1.5


# Creacion de las tiendas

mediamarkt= Tienda('MediaMarkt','Calle calle 4', 18, [3,16,78,4,34,56,39,13,4,56,7,76])
lidl= Tienda('lidl','Calle calle avenida 4', 12, [3,16,78,4,2345])
pepe= Tienda('Pepe','Avenida calle 4', 2, [3,4,2,1,146])

# Pruebas de los procedimientos

print(dir(lidl))

print(mediamarkt.sumaventas())

print(lidl.ventasempleado())

print(pepe.tiendadir())

print(mediamarkt.ventasmes())

print(mediamarkt.ventas3meses(1200))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'abierta', 'direccion', 'empleados', 'nombre', 'sumaventas', 'tiendadir', 'tipo', 'ventas', 'ventas3meses', 'ventasempleado', 'ventasmes']
# 386
# 203.83333333333334
# ('Pepe', 'Avenida calle 4')
# [76, 7, 56, 4]
# 579.0

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
# Clase y constructor

class Perro:
    '''
    Tiene 4 atrubutos
    Patas
    Orejas
    Ojos
    Velocidad
    '''
    patas=4
    orejas=2
    ojos=2
    velocidad=0

    def __init__ (self,raza,pelo='Marron',dueño=False):
        self.raza=raza
        self.pelo=pelo
        self.dueño=dueño

# Funcion para aumentar la velocidad del perro

    def velocidad_perro(perro,aumento_velocidad):
        return perro.velocidad + aumento_velocidad
# Funcion para parar el perro
    def parar(perro):
        perro.velocidad=0
        return perro.velocidad
# Funcion para ladrar
    def ladrar(perro):
        return perro.raza + ' GUAU!'

terrier=Perro('American Terrier','Blanco y negro', False)

print (terrier)
# Comprobar atributos perro creado
print(dir(terrier))

# Prueba velocidad

print(terrier.velocidad_perro(3))

# Prueba parar el perro

print (terrier.parar())

# Prueba ladrar
print(terrier.ladrar())
# Out:
# ...
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'dueño', 'ladrar', 'ojos', 'orejas', 'parar', 'patas', 'pelo', 'raza', 'velocidad', 'velocidad_perro']
# 3
# 0
# American Terrier GUAU!
